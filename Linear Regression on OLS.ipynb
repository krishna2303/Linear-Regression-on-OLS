# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
dataset = pd.read_csv('HousePrices.csv')

# %%
dataset.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# ...

# %%
dataset.shape
# Out:
# (2073, 81)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
dataset.describe()
# Out:
#                 Id   Dwell_Type  LotFrontage        LotArea  OverallQual  \
# count  2073.000000  2073.000000  1753.000000    2073.000000  2073.000000
# mean    916.132176    60.556199    72.056475   10717.853353     6.233478
# std     493.014670   159.924810    27.987475    9215.982306     1.517115
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     519.000000    20.000000    60.000000    7620.000000     5.000000
# 50%     932.000000    50.000000    70.000000    9492.000000     6.000000
# 75%    1302.000000    70.000000    83.000000   11601.000000     7.000000
# max    1820.000000  7080.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2073.000000  2073.000000   2073.000000  2059.000000  2073.000000  ...
# mean      5.835022  1969.445731   1986.617463   101.875668   437.949349  ...
# std       1.360214    30.222647     20.432694   179.169217   448.051119  ...
# ...

# %%
dataset.isnull().sum()
# Out:
# Id                       0
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            320
# LotArea                  0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 81, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Id', 'Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Alley', 'Property_Shape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'Dwelling_Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
plt.subplots(figsize=(12,9))
sns.distplot(dataset['Property_Sale_Price'], fit=stats.norm)

# Get the fitted parameters used by the function

(mu, sigma) = stats.norm.fit(dataset['Property_Sale_Price'])

# plot with the distribution

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

#Probablity plot

fig = plt.figure()
stats.probplot(dataset['Property_Sale_Price'], plot=plt)
plt.show()

# %%
#we use log function which is in numpy
dataset['Property_Sale_Price'] = np.log1p(dataset['Property_Sale_Price'])

#Check again for more normal distribution

plt.subplots(figsize=(12,9))
sns.distplot(dataset['Property_Sale_Price'], fit=stats.norm)

# Get the fitted parameters used by the function

(mu, sigma) = stats.norm.fit(dataset['Property_Sale_Price'])

# plot with the distribution

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

#Probablity plot

fig = plt.figure()
stats.probplot(dataset['Property_Sale_Price'], plot=plt)
plt.show()

# %%
#Let's check if the data set has any missing values. 
dataset.columns[dataset.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
#plot of missing value
plt.figure(figsize=(12, 6))
sns.heatmap(dataset.isnull())
plt.show()

# %%
#missing value counts in each of these columns
Isnull = dataset.isnull().sum()
Isnull = Isnull[Isnull>0]
Isnull.sort_values(inplace = True,ascending=False)
Isnull
# Out:
# PoolQC          2065
# MiscFeature     1993
# Alley           1944
# Fence           1669
# FireplaceQu      988
# LotFrontage      320
# GarageYrBlt      113
# GarageType       113
# GarageFinish     113
# GarageQual       113
# GarageCond       113
# BsmtExposure      61
# BsmtFinType2      60
# BsmtFinType1      59
# BsmtCond          59
# BsmtQual          59
# MasVnrArea        14
# MasVnrType        14
# Electrical         1
# dtype: int64

# %%
#Convert into dataframe
Isnull = Isnull.to_frame()
Isnull.columns = ['count']
Isnull.index.names = ['Name']
Isnull['Name'] = Isnull.index

# %%
#plot Missing values
plt.figure(figsize=(13, 5))
sns.set(style='whitegrid')
sns.barplot(x='Name', y='count', data=Isnull)
plt.xticks(rotation = 90)
plt.show()

# %%
#Separate variable into new dataframe from original dataframe which has only numerical values
#there is 38 numerical attribute from 81 attributes
dataset_num = dataset.select_dtypes(include=[np.number])

# %%
dataset_num.shape
# Out:
# (2073, 38)

# %%
#Coralation plot
corr = dataset_num.corr()
plt.subplots(figsize=(30,15))
sns.heatmap(corr, annot=True)

# %%
top_feature = corr.index[abs(corr['Property_Sale_Price']>0.5)]
plt.subplots(figsize=(12, 8))
top_corr = dataset[top_feature].corr()
sns.heatmap(top_corr, annot=True)
plt.show()

# %%
print("Find most important features relative to target")
corr = dataset.corr()
corr.sort_values(['Property_Sale_Price'], ascending=False, inplace=True)
corr.Property_Sale_Price
# Out:
# Find most important features relative to target
# Property_Sale_Price    1.000000
# GrLivArea              0.707143
# GarageCars             0.668622
# GarageArea             0.641719
# TotalBsmtSF            0.618530
# 1stFlrSF               0.591872
# FullBath               0.585053
# OverallQual            0.539663
# YearRemodAdd           0.525429
# TotRmsAbvGrd           0.519452
# GarageYrBlt            0.516647
# Fireplaces             0.490734
# YearBuilt              0.484011
# MasVnrArea             0.435329
# BsmtFinSF1             0.359147
# OpenPorchSF            0.353617
# WoodDeckSF             0.335283
# 2ndFlrSF               0.331752
# HalfBath               0.325267
# LotFrontage            0.287882
# BsmtUnfSF              0.238884
# BsmtFullBath           0.226502
# LotArea                0.207383
# BedroomAbvGr           0.201067
# ScreenPorch            0.120033
# PoolArea               0.064702
# 3SsnPorch              0.059859
# ...

# %%
Isnull
# Out:
#               count          Name
# Name
# PoolQC         2065        PoolQC
# MiscFeature    1993   MiscFeature
# Alley          1944         Alley
# Fence          1669         Fence
# FireplaceQu     988   FireplaceQu
# LotFrontage     320   LotFrontage
# GarageYrBlt     113   GarageYrBlt
# GarageType      113    GarageType
# GarageFinish    113  GarageFinish
# GarageQual      113    GarageQual
# GarageCond      113    GarageCond
# BsmtExposure     61  BsmtExposure
# BsmtFinType2     60  BsmtFinType2
# BsmtFinType1     59  BsmtFinType1
# BsmtCond         59      BsmtCond
# BsmtQual         59      BsmtQual
# MasVnrArea       14    MasVnrArea
# MasVnrType       14    MasVnrType
# Electrical        1    Electrical

# %%
dataset['PoolQC'] = dataset['PoolQC'].fillna('None')
dataset['MiscFeature'] = dataset['MiscFeature'].fillna('None')
dataset['Alley'] = dataset['Alley'].fillna('None')
dataset['Fence'] = dataset['Fence'].fillna('None')
dataset['FireplaceQu'] = dataset['FireplaceQu'].fillna('None')

# %%
dataset['LotFrontage'].unique
# Out:
# <bound method Series.unique of 0        65.0
# 1        80.0
# 2        68.0
# 3        60.0
# 4        84.0
#         ...
# 2068      NaN
# 2069     63.0
# 2070    313.0
# 2071     52.0
# 2072     98.0
# Name: LotFrontage, Length: 2073, dtype: float64>

# %%
dataset['LotFrontage'] = dataset["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))

# %%
for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']:
    dataset[col] = dataset[col].fillna('None')

# %%
for col in ['GarageYrBlt', 'GarageArea', 'GarageCars']:
    dataset[col] = dataset[col].fillna(int(0))

# %%
for col in ('BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtCond', 'BsmtQual'):
    dataset[col] = dataset[col].fillna('None')

# %%
dataset['MasVnrArea'] = dataset['MasVnrArea'].fillna(int(0))
dataset['MasVnrType'] = dataset['MasVnrType'].fillna('None')
dataset['Electrical'] = dataset['Electrical'].fillna(dataset['Electrical']).mode()[0]

# %%
dataset = dataset.drop(['Utilities'], axis=1)

# %%
dataset_num = dataset.select_dtypes(include=[np.number])

# %%
dataset_num.shape
# Out:
# (2073, 38)

# %%
dataset_col = dataset.select_dtypes(object)

# %%
dataset_col.shape
# Out:
# (2073, 42)

# %%
cols = ('Zone_Class','Road_Type','Alley','Property_Shape','LandContour',
        'LotConfig','Neighborhood','Condition1','Condition2','Dwelling_Type',
        'HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType',
        'Foundation','Heating','CentralAir','Electrical','GarageType','PavedDrive',
        'MiscFeature','SaleType','SaleCondition')

# %%
from sklearn.preprocessing import LabelEncoder
for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(dataset[c].values)) 
    dataset[c] = lbl.transform(list(dataset[c].values))

# %%
#Take targate variable into y
y = dataset['Property_Sale_Price']

# %%
#Delete the saleprice
del dataset['Property_Sale_Price']

# %%
X = dataset

# %%
# Split data into train and test 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (1658, 79) (1658,) (415, 79) (415,)

# %%
#Train the model
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
#Fit the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Score/Accuracy
print("Accuracy --> ", model.score(X_test, y_test)*100)
# Out:
# Accuracy -->  76.15295731029588

# %%
#Predition
y_pred = model.predict(X_test)

# %%
difference = y_test - y_pred

# %%
difference
# Out:
# 951     0.093662
# 1912    0.097168
# 374     0.065850
# 262    -0.057775
# 1985    0.237458
#           ...
# 410    -0.485521
# 281    -0.082406
# 1478    0.097803
# 1708    0.129133
# 977    -0.010646
# Name: Property_Sale_Price, Length: 415, dtype: float64
